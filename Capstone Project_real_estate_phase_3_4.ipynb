# %% [markdown]
# # CAPSTONE PROJECT -- REAL ESTATE

# %%
# importing the necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the 1st dataset 
df1=pd.read_csv("table_1_data.csv")
df1.head(10)
# Out:
#    Sr_no  Sr No         Address       City State Code Country  Rental Price  \
# 0      1      1        Kankaria  Ahmedabad    Gujarat   India         19000
# 1      2      2        Kankaria  Ahmedabad    Gujarat   India         13000
# 2      3      3     Gordhanwadi  Ahmedabad    Gujarat   India         27000
# 3      4      4        Kankaria  Ahmedabad    Gujarat   India         27000
# 4      5      5        Kankaria  Ahmedabad    Gujarat   India         15000
# 5      6      6         Rambagh  Ahmedabad    Gujarat   India         19000
# 6      7      7         Rambagh  Ahmedabad    Gujarat   India         16000
# 7      8      8         Rambagh  Ahmedabad    Gujarat   India         15000
# 8      9      9     Bhairavnath  Ahmedabad    Gujarat   India         27000
# 9     10     10  Maninagar East  Ahmedabad    Gujarat   India         23000
#
#    Deposit
# 0    38000
# 1    26000
# 2    54000
# 3    54000
# 4    30000
# 5    38000
# 6    32000
# 7    30000
# 8    54000
# 9    46000

# %%
#Loading the 2nd dataset 
df2=pd.read_csv("table_2_data.csv")
pd.options.display.max_columns=None
df2.head(10)
# Out:
#    Sr_no  Sr No  No of Beds  No of Bathroom    Area Pets Allowed
# 0      1      1           2               2  1,125            No
# 1      2      2           2               2  1,200            No
# 2      3      3           3               3  1,720            No
# 3      4      4           3               3  1,820            No
# 4      5      5           2               2  1,120            No
# 5      6      6           2               2  1,120            No
# 6      7      7           2               2  1,080            No
# 7      8      8           2               2  1,088            No
# 8      9      9           3               3  1,870            No
# 9     10     10           2               2  1,102            No

# %%
#Loading the 3rd dataset 
df3=pd.read_csv("table_3_data.csv")
pd.options.display.max_columns=None
df3.tail(10)
# Out:
#       Sr_no  Sr No Washer/Dryer  AC Parking Fireplace Dishwasher Woodenfloors  \
# 5165   5166    210           no  no     yes        no         no           no
# 5166   5167    211           no  no      no        no         no           no
# 5167   5168    212           no  no     yes        no         no           no
# 5168   5169    213           no  no     yes        no         no           no
# 5169   5170    214           no  no     yes        no         no           no
# 5170   5171    215           no  no     yes        no         no           no
# 5171   5172    216           no  no     yes        no         no           no
# 5172   5173    217           no  no     yes        no         no           no
# 5173   5174    218           no  no     yes        no         no           no
# 5174   5175    219           no  no     yes        no         no           no
#
#      roof_deck storage
# 5165        no      no
# 5166        no      no
# 5167        no      no
# 5168        no      no
# 5169        no      no
# 5170        no      no
# 5171        no      no
# 5172        no      no
# 5173        no      no
# 5174        no      no

# %%
# Merging df1 and df2 on 'Sr_no'
merged_df_1_2 = pd.merge(df1, df2, on='Sr_no')

# Merging the result with df3 on 'Sr_no'
df = pd.merge(merged_df_1_2, df3, on='Sr_no')
df
# Out:
#       Sr_no  Sr No_x      Address       City State Code Country  Rental Price  \
# 0         1        1     Kankaria  Ahmedabad    Gujarat   India         19000
# 1         2        2     Kankaria  Ahmedabad    Gujarat   India         13000
# 2         3        3  Gordhanwadi  Ahmedabad    Gujarat   India         27000
# 3         4        4     Kankaria  Ahmedabad    Gujarat   India         27000
# 4         5        5     Kankaria  Ahmedabad    Gujarat   India         15000
# ...     ...      ...          ...        ...        ...     ...           ...
# 5170   5171      215   Sheikhpura      Patna      Bihar   India         25000
# 5171   5172      216   Sheikhpura      Patna      Bihar   India         18000
# 5172   5173      217   Sheikhpura      Patna      Bihar   India          7500
# 5173   5174      218   Sheikhpura      Patna      Bihar   India         20000
# 5174   5175      219   Sheikhpura      Patna      Bihar   India          4500
#
#       Deposit  Sr No_y  No of Beds  No of Bathroom    Area Pets Allowed  \
# 0       38000        1           2               2  1,125            No
# 1       26000        2           2               2  1,200            No
# 2       54000        3           3               3  1,720            No
# 3       54000        4           3               3  1,820            No
# 4       30000        5           2               2  1,120            No
# ...       ...      ...         ...             ...     ...          ...
# 5170    50000      215           3               3  1,450            No
# 5171    36000      216           3               3  1,550            No
# 5172    15000      217           2               2    750            No
# 5173    40000      218           3               3  1,700            No
# 5174     9000      219           1               1    350            No
#
#       Sr No Washer/Dryer  AC Parking Fireplace Dishwasher Woodenfloors  \
# 0         1           no  no     yes        no         no           no
# 1         2           no  no      no        no         no           no
# 2         3           no  no     yes        no         no           no
# 3         4           no  no      no        no         no           no
# 4         5           no  no     yes        no         no           no
# ...     ...          ...  ..     ...       ...        ...          ...
# 5170    215           no  no     yes        no         no           no
# 5171    216           no  no     yes        no         no           no
# 5172    217           no  no     yes        no         no           no
# 5173    218           no  no     yes        no         no           no
# 5174    219           no  no     yes        no         no           no
#
#      roof_deck storage
# 0           no      no
# 1           no      no
# 2           no      no
# 3           no      no
# 4           no      no
# ...        ...     ...
# 5170        no      no
# 5171        no      no
# 5172        no      no
# 5173        no      no
# 5174        no      no
#
# [5175 rows x 22 columns]

# %% [markdown]
# ## * PHASE 3

# %% [markdown]
# ## Starting the EDA

# %%
df.shape
# Out:
# (5175, 22)

# %% [markdown]
# Obs-The merged dataframe contains 5175 Rows and 22 Columns

# %%
# Checking data types of attributes
df.dtypes
# Out:
# Sr_no              int64
# Sr No_x            int64
# Address           object
# City              object
# State Code        object
# Country           object
# Rental Price       int64
# Deposit            int64
# Sr No_y            int64
# No of Beds         int64
# No of Bathroom     int64
# Area              object
# Pets Allowed      object
# Sr No              int64
# Washer/Dryer      object
# AC                object
# Parking           object
# Fireplace         object
# Dishwasher        object
# Woodenfloors      object
# roof_deck         object
# storage           object
# dtype: object

# %% [markdown]
# Obs- The dataset contains both numeric as well as categorical values

# %%
# Deleting Sr no columns , as it is repeted columns and not needed for model building
df.drop(columns='Sr No_x',axis=1,inplace=True)
df.drop(columns='Sr No_y',axis=1,inplace=True)
df.drop(columns='Sr No',axis=1,inplace=True)

# %%
df.drop(columns='Sr_no',axis=1,inplace=True)

# %%
df
# Out:
#           Address       City State Code Country  Rental Price  Deposit  \
# 0        Kankaria  Ahmedabad    Gujarat   India         19000    38000
# 1        Kankaria  Ahmedabad    Gujarat   India         13000    26000
# 2     Gordhanwadi  Ahmedabad    Gujarat   India         27000    54000
# 3        Kankaria  Ahmedabad    Gujarat   India         27000    54000
# 4        Kankaria  Ahmedabad    Gujarat   India         15000    30000
# ...           ...        ...        ...     ...           ...      ...
# 5170   Sheikhpura      Patna      Bihar   India         25000    50000
# 5171   Sheikhpura      Patna      Bihar   India         18000    36000
# 5172   Sheikhpura      Patna      Bihar   India          7500    15000
# 5173   Sheikhpura      Patna      Bihar   India         20000    40000
# 5174   Sheikhpura      Patna      Bihar   India          4500     9000
#
#       No of Beds  No of Bathroom    Area Pets Allowed Washer/Dryer  AC  \
# 0              2               2  1,125            No           no  no
# 1              2               2  1,200            No           no  no
# 2              3               3  1,720            No           no  no
# 3              3               3  1,820            No           no  no
# 4              2               2  1,120            No           no  no
# ...          ...             ...     ...          ...          ...  ..
# 5170           3               3  1,450            No           no  no
# 5171           3               3  1,550            No           no  no
# 5172           2               2    750            No           no  no
# 5173           3               3  1,700            No           no  no
# 5174           1               1    350            No           no  no
#
#      Parking Fireplace Dishwasher Woodenfloors roof_deck storage
# 0        yes        no         no           no        no      no
# 1         no        no         no           no        no      no
# 2        yes        no         no           no        no      no
# 3         no        no         no           no        no      no
# 4        yes        no         no           no        no      no
# ...      ...       ...        ...          ...       ...     ...
# 5170     yes        no         no           no        no      no
# 5171     yes        no         no           no        no      no
# 5172     yes        no         no           no        no      no
# 5173     yes        no         no           no        no      no
# 5174     yes        no         no           no        no      no
#
# [5175 rows x 18 columns]

# %%
# Checking for null values if any
df.isnull().sum()
# Out:
# Address           0
# City              0
# State Code        0
# Country           0
# Rental Price      0
# Deposit           0
# No of Beds        0
# No of Bathroom    0
# Area              0
# Pets Allowed      0
# Washer/Dryer      0
# AC                0
# Parking           0
# Fireplace         0
# Dishwasher        0
# Woodenfloors      0
# roof_deck         0
# storage           0
# dtype: int64

# %%
#heatmap for null values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# Obs- We can see no null values are present in dataframe

# %%
# checking for white space
# Iterate through each column of the dataframe and check for white spaces
for col in df.columns:
    # Count the number of white spaces in the column
    num_spaces = sum(df[col].astype(str).apply(lambda x: x.isspace()))

    # Display the results
    print(f"Column '{col}' has {num_spaces} white spaces.")
# Out:
# Column 'Address' has 0 white spaces.
# Column 'City' has 0 white spaces.
# Column 'State Code' has 0 white spaces.
# Column 'Country' has 0 white spaces.
# Column 'Rental Price' has 0 white spaces.
# Column 'Deposit' has 0 white spaces.
# Column 'No of Beds' has 0 white spaces.
# Column 'No of Bathroom' has 0 white spaces.
# Column 'Area' has 0 white spaces.
# Column 'Pets Allowed' has 0 white spaces.
# Column 'Washer/Dryer' has 0 white spaces.
# Column 'AC' has 0 white spaces.
# Column 'Parking' has 0 white spaces.
# Column 'Fireplace' has 0 white spaces.
# Column 'Dishwasher' has 0 white spaces.
# Column 'Woodenfloors' has 0 white spaces.
# Column 'roof_deck' has 0 white spaces.
# Column 'storage' has 0 white spaces.

# %% [markdown]
# obs-There is no white space in the dataset

# %%
#Check for duplicate data
df.duplicated().sum()
# Out:
# 101

# %% [markdown]
# Obs- We can see duplicate data is present in the dataset

# %%
# let's drop duplicate data

df.drop_duplicates()
# Out:
#           Address       City State Code Country  Rental Price  Deposit  \
# 0        Kankaria  Ahmedabad    Gujarat   India         19000    38000
# 1        Kankaria  Ahmedabad    Gujarat   India         13000    26000
# 2     Gordhanwadi  Ahmedabad    Gujarat   India         27000    54000
# 3        Kankaria  Ahmedabad    Gujarat   India         27000    54000
# 4        Kankaria  Ahmedabad    Gujarat   India         15000    30000
# ...           ...        ...        ...     ...           ...      ...
# 5170   Sheikhpura      Patna      Bihar   India         25000    50000
# 5171   Sheikhpura      Patna      Bihar   India         18000    36000
# 5172   Sheikhpura      Patna      Bihar   India          7500    15000
# 5173   Sheikhpura      Patna      Bihar   India         20000    40000
# 5174   Sheikhpura      Patna      Bihar   India          4500     9000
#
#       No of Beds  No of Bathroom    Area Pets Allowed Washer/Dryer  AC  \
# 0              2               2  1,125            No           no  no
# 1              2               2  1,200            No           no  no
# 2              3               3  1,720            No           no  no
# 3              3               3  1,820            No           no  no
# 4              2               2  1,120            No           no  no
# ...          ...             ...     ...          ...          ...  ..
# 5170           3               3  1,450            No           no  no
# 5171           3               3  1,550            No           no  no
# 5172           2               2    750            No           no  no
# 5173           3               3  1,700            No           no  no
# 5174           1               1    350            No           no  no
#
#      Parking Fireplace Dishwasher Woodenfloors roof_deck storage
# 0        yes        no         no           no        no      no
# 1         no        no         no           no        no      no
# 2        yes        no         no           no        no      no
# 3         no        no         no           no        no      no
# 4        yes        no         no           no        no      no
# ...      ...       ...        ...          ...       ...     ...
# 5170     yes        no         no           no        no      no
# 5171     yes        no         no           no        no      no
# 5172     yes        no         no           no        no      no
# 5173     yes        no         no           no        no      no
# 5174     yes        no         no           no        no      no
#
# [5074 rows x 18 columns]

# %% [markdown]
# Obs- We can see the row count has reduced by 101 count. and the duplicate data is removed

# %%
# removing (,comma) from area column
df['Area'] = df['Area'].str.replace(',', '').astype(int)

# %%
df.tail(10)
# Out:
#                     Address   City State Code Country  Rental Price  Deposit  \
# 5165        Phulwari Sharif  Patna      Bihar   India          8000    16000
# 5166  Ashiana Nagar Phase 1  Patna      Bihar   India          5500    11000
# 5167  Ashiana Nagar Phase 1  Patna      Bihar   India         21000    42000
# 5168  Ashiana Nagar Phase 1  Patna      Bihar   India         13000    26000
# 5169     Jagat Vihar Colony  Patna      Bihar   India         26000    52000
# 5170             Sheikhpura  Patna      Bihar   India         25000    50000
# 5171             Sheikhpura  Patna      Bihar   India         18000    36000
# 5172             Sheikhpura  Patna      Bihar   India          7500    15000
# 5173             Sheikhpura  Patna      Bihar   India         20000    40000
# 5174             Sheikhpura  Patna      Bihar   India          4500     9000
#
#       No of Beds  No of Bathroom  Area Pets Allowed Washer/Dryer  AC Parking  \
# 5165           2               2   995           No           no  no     yes
# 5166           1               1   800           No           no  no      no
# 5167           3               3  1300           No           no  no     yes
# 5168           2               2  1296           No           no  no     yes
# 5169           2               2  1100           No           no  no     yes
# 5170           3               3  1450           No           no  no     yes
# 5171           3               3  1550           No           no  no     yes
# 5172           2               2   750           No           no  no     yes
# 5173           3               3  1700           No           no  no     yes
# 5174           1               1   350           No           no  no     yes
#
#      Fireplace Dishwasher Woodenfloors roof_deck storage
# 5165        no         no           no        no      no
# 5166        no         no           no        no      no
# 5167        no         no           no        no      no
# 5168        no         no           no        no      no
# 5169        no         no           no        no      no
# 5170        no         no           no        no      no
# 5171        no         no           no        no      no
# 5172        no         no           no        no      no
# 5173        no         no           no        no      no
# 5174        no         no           no        no      no

# %%
#Checking description of dataset
df.describe()
# Out:
#        Rental Price       Deposit   No of Beds  No of Bathroom          Area
# count  5.175000e+03  5.175000e+03  5175.000000     5175.000000   5175.000000
# mean   3.864836e+04  7.729673e+04     2.344734        2.344734   1390.166763
# std    8.051946e+04  1.610389e+05     0.992920        0.992920    986.677202
# min    1.500000e+03  3.000000e+03     1.000000        1.000000     84.000000
# 25%    1.300000e+04  2.600000e+04     2.000000        2.000000    800.000000
# 50%    2.000000e+04  4.000000e+04     2.000000        2.000000   1200.000000
# 75%    3.500000e+04  7.000000e+04     3.000000        3.000000   1750.000000
# max    2.000000e+06  4.000000e+06    12.000000       12.000000  15000.000000

# %%
# description using heatmap
plt.figure(figsize=(20,20))
sns.heatmap(df.describe(),annot=True,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Obs- We can see:
# * Count is same for all column
# * The mean in columns:'Rental Price', 'Deposit','Area' is greater than median and thus we can say Right Skewness is present in these columns.
#
# * The max of columns 'No of Beds',No of Bathroom' is exceptionally greter than 75% , so we can predict outliers must be present in these columns

# %%
# Checking the Unique Values in each column
df.nunique()
# Out:
# Address           1537
# City                48
# State Code          17
# Country              1
# Rental Price       345
# Deposit            345
# No of Beds          11
# No of Bathroom      11
# Area               749
# Pets Allowed         1
# Washer/Dryer         1
# AC                   1
# Parking              2
# Fireplace            1
# Dishwasher           1
# Woodenfloors         1
# roof_deck            1
# storage              1
# dtype: int64

# %%
#Seperating Numerical and Categorical Column
cat_cols = [x for x in df.columns if df[x].dtypes=='O']

num_cols = [y for y in df.columns if df[y].dtypes!='O']

# %%
cat_cols
# Out:
# ['Address',
#  'City',
#  'State Code',
#  'Country',
#  'Pets Allowed',
#  'Washer/Dryer',
#  'AC',
#  'Parking',
#  'Fireplace',
#  'Dishwasher',
#  'Woodenfloors',
#  'roof_deck',
#  'storage']

# %%
num_cols
# Out:
# ['Rental Price', 'Deposit', 'No of Beds', 'No of Bathroom', 'Area']

# %%
print(f"Mean Rent: {df['Rental Price'].mean()}")
print(f"Median Rent: {df['Rental Price'].median()}")
print(f"Highest Rent: {df['Rental Price'].max()}")
print(f"Lowest Rent: {df['Rental Price'].min()}")
# Out:
# Mean Rent: 38648.36463768116
# Median Rent: 20000.0
# Highest Rent: 2000000
# Lowest Rent: 1500

# %% [markdown]
# As we can see Highest Rent is Rs. 2000000 and lowest rent is Rs. 1500.

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### 1. Univariate Analysis

# %%
# Count plot to check no of cities in India
print(df['City'].value_counts()[:13])
plt.figure(figsize=(12,5))
sns.countplot(df['City'],order=pd.value_counts(df['City']).iloc[:13].index)
plt.xticks(rotation=90)
plt.show()
# Out:
# Kolkata      608
# Hyderabad    590
# Gurgaon      522
# Bangalore    499
# Jaipur       493
# Bhopal       469
# Mumbai       426
# Mohali       365
# Dehradun     241
# Ahmedabad    224
# Chennai      221
# Patna        218
# Pune         213
# Name: City, dtype: int64

# %% [markdown]
# Obs- We can see 'Kolkata' has max no. of rental properties, followed by 'Hyderabad','Gurgoan', 'Bangalore','Jaipur' and so on

# %%
# Count plot to check rental properties State wise in India
print(df['State Code'].value_counts()[:13])
plt.figure(figsize=(12,5))
sns.countplot(df['State Code'],order=pd.value_counts(df['State Code']).iloc[:13].index)
plt.xticks(rotation=90)
plt.show()
# Out:
# Maharashtra       639
# West Bengal       608
# Telangana         590
# Haryana           522
# Karnataka         499
# Rajasthan         493
# Madhya Pradesh    469
# Punjab            375
# Uttarakhand       241
# Gujarat           224
# Tamil Nadu        221
# Bihar             219
# Chandigarh         38
# Name: State Code, dtype: int64

# %% [markdown]
# - As we can see, In dataframe,maximum rental properties are avilable from Maharashtra followed by West Bengal,Telangana,Haryana and so on

# %%
#Histogram to check distribution country wise
plt.figure(figsize=(25,8))
sns.histplot(df['Country'],color='m')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Obs- We can see In our dataframe,rental properties from different cities in India.

# %%
#Violin to check distribution Area of Rental Properties
plt.figure(figsize=(10,6))
sns.violinplot(df['Area'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Obs- We can see the dataframe contains Area of rental properties in between 1000 sqft to 2000sq ft.

# %%
#HISTOGRAM to check distribution of Rental Price
plt.figure(figsize=(12,6))
sns.histplot(df['Rental Price'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Obs- We can see large no. of rental properties rent is in between 10 thousand to 15 thousands.

# %%
#HISTOGRAM to check distribution no of bedrooms
plt.figure(figsize=(12,6))
sns.histplot(df['No of Beds'],color='y')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Obs- We can see maximum rental properties are available having 2 and 3 bedrooms.

# %%
# Count plot to check Parking availability in rental properties
sns.countplot(x='Parking',data=df)
# Out:
# <AxesSubplot:xlabel='Parking', ylabel='count'>

# %%
# Count plot to check amenities availability in rental properties
amenity_list = ['Washer/Dryer',
 'AC',
 'Parking',
 'Fireplace',
 'Dishwasher',
 'Woodenfloors',
 'roof_deck',
 'storage']
for amenity in amenity_list:
    plt.figure(figsize=(8, 6))
    sns.countplot(x=amenity, data=df)
    plt.title(f'Count of {amenity}')
    plt.show()

# %% [markdown]
# Obs- As we can see,maximum rental properties having no amenities provide in India except Parking.

# %%
# Count plot to check pets allowed in rental properties
sns.countplot(x='Pets Allowed',data=df)
# Out:
# <AxesSubplot:xlabel='Pets Allowed', ylabel='count'>

# %% [markdown]
# - As per our database pets are not allowed in rental properties.

# %%
# Distribution plot to check skewness

# %%
plt.figure(figsize=(30,20))
plotnumber=1

for column in df[num_cols]:
    if plotnumber<=5: #as there are 6 numerical columns 
        ax=plt.subplot(2,3,plotnumber)
        sns.distplot(df[column],color='c')
        plt.xlabel(column,fontsize=25)
    plotnumber +=1
plt.show()

# %% [markdown]
# Obs- We can see Right skewness in columns: 'Rental Price', 'Deposit', 'Area'columns

# %%
#box plot to check outliers

# %%
df[num_cols].plot(kind='box',subplots=True,layout=(2,3),figsize=(20,14))
plt.show()

# %% [markdown]
# Obs- Wev can see outliers are present in all the numeical columns

# %% [markdown]
# ### Bivariate Analysis & Multivariate Analysis

# %%
# Rent in different cities
plt.figure(figsize=(12, 5))
sns.scatterplot('City','Rental Price',data=df)
plt.title("Rent in Different Cities")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Obs- We can see Rental price in Mumbai,Hyderabad,Bangalore is Higher than other cities

# %%
#  list of columns to be analyszed numerically for all cities
overall_numerical_cols = ['Rental Price','Area','Deposit']

# %%
for col in overall_numerical_cols:
    fig, ax = plt.subplots(figsize=(30, 20))
    mean_df = df.groupby(by=['City'])[col].mean()
    mean_df.sort_values(inplace=True, ascending=False)
    sns.barplot(x=mean_df.index, y=mean_df, ax=ax)
    ax.set_xlabel('City')
    ax.set_ylabel(f'AVERAGE {col}')
    ax.set_title(f'AVERAGE {col} IN EACH CITY')
    
    plt.show()

# %%
# Line Plot to check relationship between Area and Rental Price
plt.figure(figsize=(10,7))
sns.lineplot(df['Area'],df['Rental Price'],color='m')
plt.xlabel('Area')
plt.ylabel('Rental Price')
plt.show()

# %% [markdown]
# Obs- We can see as Area is increasing, Rental price also incresing

# %%
# Rent in different cities
plt.figure(figsize=(12, 5))
sns.scatterplot('No of Beds','Rental Price',data=df)
plt.title("Rent according to no of beds")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Obs- We can see Rental price is high for 3,4 and 5 no of beds in rental properties

# %% [markdown]
# # Here dropping columns like 'Country', 'Pets Allowed', 'Washer/Dryer', 'AC', 'Fireplace', 'Dishwasher', 'Woodenfloors', 'roof_deck', 'storage' because all the data in DataFrame pertains to Indian cities, and these amenities are not typically provided for rental properties in Indian cities

# %%
df.drop('Country',axis=1,inplace=True)
df.drop('Pets Allowed',axis=1,inplace=True)
df.drop('Washer/Dryer',axis=1,inplace=True)
df.drop('AC',axis=1,inplace=True)
df.drop('Fireplace',axis=1,inplace=True)
df.drop('Dishwasher',axis=1,inplace=True)
df.drop('roof_deck',axis=1,inplace=True)
df.drop('storage',axis=1,inplace=True)

# %%
df.drop('Woodenfloors',axis=1,inplace=True)

# %%
# Again Seperating Numerical and Categorical Column
cat_cols = [x for x in df.columns if df[x].dtypes=='O']

num_cols = [y for y in df.columns if df[y].dtypes!='O']

# %% [markdown]
# ## Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
for col in df[cat_cols]:  
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
df.dtypes
# Out:
# Address           int32
# City              int32
# State Code        int32
# Rental Price      int64
# Deposit           int64
# No of Beds        int64
# No of Bathroom    int64
# Area              int32
# Parking           int32
# dtype: object

# %% [markdown]
# Obs- We can see all the columns have been encoded properly

# %% [markdown]
# ## Checking Correlation

# %%
df.corr()
# Out:
#                  Address      City  State Code  Rental Price   Deposit  \
# Address         1.000000  0.021487   -0.005179     -0.044125 -0.044125
# City            0.021487  1.000000    0.111414      0.119515  0.119515
# State Code     -0.005179  0.111414    1.000000     -0.061921 -0.061921
# Rental Price   -0.044125  0.119515   -0.061921      1.000000  1.000000
# Deposit        -0.044125  0.119515   -0.061921      1.000000  1.000000
# No of Beds     -0.014706 -0.107313   -0.079757      0.315804  0.315804
# No of Bathroom -0.014706 -0.107313   -0.079757      0.315804  0.315804
# Area           -0.009799 -0.076627   -0.019091      0.388910  0.388910
# Parking        -0.042760  0.199411   -0.058274      0.090967  0.090967
#
#                 No of Beds  No of Bathroom      Area   Parking
# Address          -0.014706       -0.014706 -0.009799 -0.042760
# City             -0.107313       -0.107313 -0.076627  0.199411
# State Code       -0.079757       -0.079757 -0.019091 -0.058274
# Rental Price      0.315804        0.315804  0.388910  0.090967
# Deposit           0.315804        0.315804  0.388910  0.090967
# No of Beds        1.000000        1.000000  0.632065 -0.000597
# No of Bathroom    1.000000        1.000000  0.632065 -0.000597
# Area              0.632065        0.632065  1.000000  0.013867
# Parking          -0.000597       -0.000597  0.013867  1.000000

# %%
# Correlation using heatmap
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %%
# Correlation of features with Target Column a)Votes
plt.figure(figsize=(12,7))
df.corr()['Rental Price'].sort_values(ascending=False).drop(['Rental Price']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Rental Price',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Obs- We can see  'Deposit' is the highly positively correlated column with Target Column 'Rental Price', followed by 'Area' and 'No of Beds', 'No of Bathroom' and city
# -- State code and Address is negatively corelated to Rental Price

# %%
# Correlation of features with Target Column a)Votes
plt.figure(figsize=(12,7))
df.corr()['Area'].sort_values(ascending=False).drop(['Area']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('Area',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Obs- We can see 'No of Beds','No of Bathrooms' are the highly positively correlated with Target Column 'Area', followed by 'Renatl Price' and 'Deposit'. 'City','State Code','Address' is negatively correlated the with 'Area'

# %% [markdown]
# ## Removing outliers using z-score

# %%
# Using Z-Score method
from scipy.stats import zscore
z=np.abs(zscore(df[num_cols])) # detecting only numerical cols
threshold=3

# %%
df_clean=df[num_cols][(z<3).all(axis=1)]

# %%
print("Data with outliers::",df.shape)
print("Data after removing outliers::",df_clean.shape)
# Out:
# Data with outliers:: (5175, 9)
# Data after removing outliers:: (5019, 5)

# %%
df.shape
# Out:
# (5175, 9)

# %%
a = df.shape[0]
b = df_clean.shape[0]

# %%
print('Data Loss Percentage - ',((a-b)/a)*100)
# Out:
# Data Loss Percentage -  3.0144927536231885

# %% [markdown]
# Obs- As the data loss is within permissable range, will delete the outliers from these numerical columns

# %%
dropindx = df.index.difference(df_clean.index)

# %%
dropindx
# Out:
# Int64Index([ 227,  252,  273,  322,  323,  324,  362,  375,  376,  386,
#             ...
#             4569, 4575, 4582, 4625, 4629, 4630, 4723, 4887, 4995, 5113],
#            dtype='int64', length=156)

# %%
df.drop(dropindx,inplace = True)

# %%
df.reset_index(drop=True,inplace = True)

# %%
df.shape
# Out:
# (5019, 9)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ## (Approach 1: 'Regression Model' to find Rental Price)

# %% [markdown]
# ### Data Preprocessing
#
# ### Seperating Input and Target variables

# %%
x1=df.drop(columns='Rental Price')
y1=df['Rental Price']
print('Features Diamension = ',x1.shape)
print('Label Diamension = ',y1.shape)
# Out:
# Features Diamension =  (5019, 8)
# Label Diamension =  (5019,)

# %% [markdown]
# ### Data Transformation to treat Skewness

# %%
x1.skew()
# Out:
# Address          -0.117403
# City              0.833791
# State Code        0.094096
# Deposit           3.803484
# No of Beds        0.253588
# No of Bathroom    0.253588
# Area              0.911816
# Parking          -0.305236
# dtype: float64

# %% [markdown]
# Obs- Keeping the acceptable range as +/-0.5, we can see skewness is present in columns: 'Area','Deposit'
#
# --  'Address','City','State Code','Parking' are categorical columns , will not treat the skewness of these columns

# %% [markdown]
# #### Applying Transformation Method

# %%
x1=pd.DataFrame(x1)
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer() 
skew_col = ['Area','Deposit'] 
x1[skew_col]= pt.fit_transform(x1[skew_col].values)

# %%
# Rechecking the skewness
x1.skew()
# Out:
# Address          -0.117403
# City              0.833791
# State Code        0.094096
# Deposit          -0.016781
# No of Beds        0.253588
# No of Bathroom    0.253588
# Area             -0.012235
# Parking          -0.305236
# dtype: float64

# %% [markdown]
# Obs- We can see skewness is removed from columns-'Area' and 'Deposit'

# %% [markdown]
# ### Data Scaling

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x1_scale=st.fit_transform(x1)
x1_scale=pd.DataFrame(x1_scale,columns=x1.columns)

# %%
x1=pd.DataFrame(data=x1_scale)

# %% [markdown]
# ### Checking Multi-Collinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vif_cal1():
    vif1=pd.DataFrame()
    vif1['VIF Factor']=[variance_inflation_factor(x1.values,i)for i in range(x1.shape[1])]
    vif1['Features']=x1.columns
    print(vif1)

vif_cal1()
# Out:
#    VIF Factor        Features
# 0    1.003520         Address
# 1    1.132430            City
# 2    1.030022      State Code
# 3    1.663505         Deposit
# 4         inf      No of Beds
# 5         inf  No of Bathroom
# 6    2.919294            Area
# 7    1.054435         Parking

# %% [markdown]
# Obs- We can see multicollinearity is not present between any columns

# %% [markdown]
# ### Data Modelling

# %%
#importing necessary libraries
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error, r2_score

from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor

from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
# Finding Best Random State
maxAccu=0
maxRS=0
for i in range(1,200):
    x1_train,x1_test,y1_train,y1_test = train_test_split(x1,y1,test_size=.25, random_state =i)
    knr = KNeighborsRegressor()
    knr.fit(x1_train, y1_train)
    pred1 = knr.predict(x1_test)
    acc=r2_score(y1_test, pred1)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.9495965345319749  on Random_state  94

# %% [markdown]
# #### Splitting data into Train-Test

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.25,random_state=maxRS)

# %%
x1_train.shape
# Out:
# (3764, 8)

# %%
y1_train.shape
# Out:
# (3764,)

# %%
x1_test.shape
# Out:
# (1255, 8)

# %%
y1_test.shape
# Out:
# (1255,)

# %% [markdown]
# ### Using various Machine Learning Algorithms

# %% [markdown]
# #### 1. Linear Regression

# %%
lr=LinearRegression()
lr.fit(x1_train,y1_train)
lr.score(x1_train,y1_train)
# Out:
# 0.61345742026341

# %%
predlr=lr.predict(x1_test)
print("The performance metrix of Linear Regression is as below \n")
print("r2_score=",r2_score(y1_test,predlr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y1_test,predlr))
print("Mean Squared Error:",mean_squared_error(y1_test,predlr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,predlr)))
# Out:
# The performance metrix of Linear Regression is as below
#
# r2_score= 0.6227518739098028
#
# Mean Absolute Error: 13081.559607798492
# Mean Squared Error: 475421524.53382
# Root Meand Squared Error: 21804.16300924711

# %% [markdown]
# #### 2. Support Vector Regressor

# %%
svr=SVR()
svr.fit(x1_train,y1_train)
svr.score(x1_train,y1_train)
# Out:
# -0.07758767894339891

# %%
predsvr=svr.predict(x1_test)
print("The performance metrix of Support Vector Regressor is as below \n")
print("r2_score=",r2_score(y1_test,predsvr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y1_test,predsvr))
print("Mean Squared Error:",mean_squared_error(y1_test,predsvr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,predsvr)))
# Out:
# The performance metrix of Support Vector Regressor is as below
#
# r2_score= -0.08153526717258575
#
# Mean Absolute Error: 17855.782524766462
# Mean Squared Error: 1362989263.552618
# Root Meand Squared Error: 36918.684477546296

# %% [markdown]
# #### 3. Decision Tree Regressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x1_train,y1_train)
dtr.score(x1_train,y1_train)
# Out:
# 1.0

# %%
preddtr=dtr.predict(x1_test)
print("The performance metrix of Decision Tree Regressor is as below \n")
print("r2_score=",r2_score(y1_test,preddtr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y1_test,preddtr))
print("Mean Squared Error:",mean_squared_error(y1_test,preddtr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,preddtr)))
# Out:
# The performance metrix of Decision Tree Regressor is as below
#
# r2_score= 0.9999519077763692
#
# Mean Absolute Error: 20.39840637450199
# Mean Squared Error: 60607.533067729084
# Root Meand Squared Error: 246.1859725242872

# %% [markdown]
# #### 4. K Neighbors Regressor

# %%
knr=KNeighborsRegressor()
knr.fit(x1_train,y1_train)
knr.score(x1_train,y1_train)
# Out:
# 0.9352040380940219

# %%
predknr=knr.predict(x1_test)
print("The performance metrix of K Neighbors Regressor is as below \n")
print("r2_score=",r2_score(y1_test,predknr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y1_test,predknr))
print("Mean Squared Error:",mean_squared_error(y1_test,predknr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,predknr)))
# Out:
# The performance metrix of K Neighbors Regressor is as below
#
# r2_score= 0.9495965345319749
#
# Mean Absolute Error: 3728.0866932270915
# Mean Squared Error: 63520242.34804782
# Root Meand Squared Error: 7969.958741928833

# %% [markdown]
# #### 5.Random Forest Regressor

# %%
rfr=RandomForestRegressor()
rfr.fit(x1_train,y1_train)
rfr.score(x1_train,y1_train)
# Out:
# 0.9999894315974895

# %%
predrfr=rfr.predict(x1_test)
print("The performance metrix of Random Forest Regressor is as below \n")
print("r2_score=",r2_score(y1_test,predrfr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y1_test,predrfr))
print("Mean Squared Error:",mean_squared_error(y1_test,predrfr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,predrfr)))
# Out:
# The performance metrix of Random Forest Regressor is as below
#
# r2_score= 0.999849172847144
#
# Mean Absolute Error: 50.30454980079683
# Mean Squared Error: 190077.74987529882
# Root Meand Squared Error: 435.97907045556536

# %% [markdown]
# #### 6.Ada Boost Regressor

# %%
adr=AdaBoostRegressor()
adr.fit(x1_train,y1_train)
adr.score(x1_train,y1_train)
# Out:
# 0.9902376336947737

# %%
predadr=adr.predict(x1_test)
print("The performance metrix of Ada Boost Regressor is as below \n")
print("r2_score=",r2_score(y1_test,predadr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y1_test,predadr))
print("Mean Squared Error:",mean_squared_error(y1_test,predadr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,predadr)))
# Out:
# The performance metrix of Ada Boost Regressor is as below
#
# r2_score= 0.990373643140339
#
# Mean Absolute Error: 2649.666046191251
# Mean Squared Error: 12131477.76599532
# Root Meand Squared Error: 3483.0270980851296

# %% [markdown]
# #### 7.Gradient Boosting Regressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x1_train,y1_train)
gbr.score(x1_train,y1_train)
# Out:
# 0.9999918795930199

# %%
predgbr=gbr.predict(x1_test)
print("The performance metrix of Gradient Boosting Regressor is as below \n")
print("r2_score=",r2_score(y1_test,predgbr),"\n")

print("Mean Absolute Error:",mean_absolute_error(y1_test,predgbr))
print("Mean Squared Error:",mean_squared_error(y1_test,predgbr))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,predgbr)))
# Out:
# The performance metrix of Gradient Boosting Regressor is as below
#
# r2_score= 0.9999402125794075
#
# Mean Absolute Error: 70.76123001234726
# Mean Squared Error: 75346.23681398877
# Root Meand Squared Error: 274.4926899099296

# %% [markdown]
# #### Regularization to overcome Over-Fitting (Lasso,Ridge)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso,Ridge

# %% [markdown]
# #### 8. Lasso Regression

# %%
ls=Lasso(alpha=0.1)
ls.fit(x1_train,y1_train)
ls.score(x1_train,y1_train)
# Out:
# 0.6134574201999015

# %%
predls=ls.predict(x1_test)
print("The performance metrix of Lasso Regressor is as below \n")
print("r2_score=",r2_score(y1_test,predls),"\n")
print("Mean Absolute Error:",mean_absolute_error(y1_test,predls))
print("Mean Squared Error:",mean_squared_error(y1_test,predls))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,predls)))
# Out:
# The performance metrix of Lasso Regressor is as below
#
# r2_score= 0.6227515686004017
#
# Mean Absolute Error: 13081.533147442542
# Mean Squared Error: 475421909.2956012
# Root Meand Squared Error: 21804.17183237192

# %% [markdown]
# #### 9. Ridge Regression

# %%
rg=Ridge(alpha=0.1)
rg.fit(x1_train,y1_train)
rg.score(x1_train,y1_train)
# Out:
# 0.6134574193707489

# %%
predrg=rg.predict(x1_test)
print("The performance metrix of Ridge Regressor is as below \n")
print("r2_score=",r2_score(y1_test,predrg),"\n")

print("Mean Absolute Error:",mean_absolute_error(y1_test,predrg))
print("Mean Squared Error:",mean_squared_error(y1_test,predrg))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,predrg)))
# Out:
# The performance metrix of Ridge Regressor is as below
#
# r2_score= 0.6227522081360113
#
# Mean Absolute Error: 13081.323505759863
# Mean Squared Error: 475421103.3300484
# Root Meand Squared Error: 21804.153350452485

# %% [markdown]
# ### Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# cv score for Linear Regression 
cvlr=cross_val_score(lr,x1,y1,cv=5).mean()
print('CV score  for Linear rgerssion:',cvlr)
print("And Difference between CV and r2_score =", r2_score(y1_test,predlr)-cvlr)
# Out:
# CV score  for Linear rgerssion: 0.3946808025290194
# And Difference between CV and r2_score = 0.22807107138078342

# %%
# cv score for Support Vector Regressor
cvsvr=cross_val_score(svr,x1,y1,cv=5).mean()
print('CV score  for Support Vector Regressor:',cvsvr)
print("And Difference between CV and r2_score =", r2_score(y1_test,predsvr)-cvsvr)
# Out:
# CV score  for Support Vector Regressor: -0.09793328336597018
# And Difference between CV and r2_score = 0.016398016193384435

# %%
# cv score for Decision Tree Regressor
cvdtr=cross_val_score(dtr,x1,y1,cv=5).mean()
print('CV score  for Decision Tree Regressor:',cvdtr)
print("And Difference between CV and r2_score =", r2_score(y1_test,preddtr)-cvdtr)
# Out:
# CV score  for Decision Tree Regressor: 0.9990817908357595
# And Difference between CV and r2_score = 0.0008701169406096776

# %%
# cv score for K Neighbors Regressor
cvknr=cross_val_score(knr,x1,y1,cv=5).mean()
print('CV score  for K Neighbors Regressor:',cvknr)
print("And Difference between CV and r2_score =", r2_score(y1_test,predknr)-cvknr)
# Out:
# CV score  for K Neighbors Regressor: 0.7129887636817948
# And Difference between CV and r2_score = 0.23660777085018014

# %%
# cv score for Random Forest Regressor
cvrfr=cross_val_score(rfr,x1,y1,cv=5).mean()
print('CV score  for Random Forest Regressor:',cvrfr)
print("And Difference between CV and r2_score =", r2_score(y1_test,predrfr)-cvrfr)
# Out:
# CV score  for Random Forest Regressor: 0.9992057106087107
# And Difference between CV and r2_score = 0.0006434622384333677

# %%
# cv score for Gradient Boosting Regressor
cvgbr=cross_val_score(gbr,x1,y1,cv=5).mean()
print('CV score  for Gradient Boosting Regressor:',cvgbr)
print("And Difference between CV and r2_score =", r2_score(y1_test,predgbr)-cvgbr)
# Out:
# CV score  for Gradient Boosting Regressor: 0.9994993048753413
# And Difference between CV and r2_score = 0.0004409077040661291

# %%
# cv score for Ada Boost Regressor
cvadr=cross_val_score(adr,x1,y1,cv=5).mean()
print('CV score  for Ada Boost Regressor:',cvadr)
print("And Difference between CV and r2_score =", r2_score(y1_test,predadr)-cvadr)
# Out:
# CV score  for Ada Boost Regressor: 0.9755310905675015
# And Difference between CV and r2_score = 0.014842552572837509

# %%
# cv score for Lasso Regressor
cvls=cross_val_score(ls,x1,y1,cv=5).mean()
print('CV score  for Lasso Regressor:',cvls)
print("And Difference between CV and r2_score =", r2_score(y1_test,predls)-cvls)
# Out:
# CV score  for Lasso Regressor: 0.3946837083886188
# And Difference between CV and r2_score = 0.22806786021178288

# %%
# cv score for Ridge Regressor
cvrg=cross_val_score(rg,x1,y1,cv=5).mean()
print('CV score  for Ridge Regressor:',cvrg)
print("And Difference between CV and r2_score =", r2_score(y1_test,predrg)-cvrg)
# Out:
# CV score  for Ridge Regressor: 0.39469075688184463
# And Difference between CV and r2_score = 0.22806145125416666

# %% [markdown]
# ##### Obs-
# * We can see Difference between CV and r2_score of Decision Tree Regressor, and Random Forest Regressor and Gradient Boosting Regressor is Less.We go with one of them i.e 'Gradient Boosting Regressor'

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
gbr.get_params() # Getting Gradient Boosting Regressor Parameters
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
#Selecting few parameter list to pass in Gradient Boosting Regressor
from sklearn.model_selection import GridSearchCV
# defining parameter range
parameter = {'criterion':['friedman_mse', 'squared_error'], 
             'loss':['squared_error', 'absolute_error', 'huber', 'quantile'],
             'random_state': [24,32,44,74,112],
             'max_features':['auto', 'sqrt', 'log2']}

# %%
# Start Tuning 
gbr1=GradientBoostingRegressor()
GCV = GridSearchCV(gbr1,parameter,cv=5)

GCV.fit(x1_train,y1_train)  
print(GCV.best_params_)
# Out:
# {'criterion': 'friedman_mse', 'loss': 'squared_error', 'max_features': 'auto', 'random_state': 32}

# %%
#Applying best parameter values on Gradient Boossting Regressor Algorithm 
rental_best=GradientBoostingRegressor(criterion='friedman_mse', loss= 'squared_error', max_features= 'auto', random_state= 32)
rental_best.fit(x1_train,y1_train)
rental_best.score(x1_train,y1_train)
# Out:
# 0.9999918795930199

# %%
predgbr1=rental_best.predict(x1_test)
print("r2_score=",r2_score(y1_test,predgbr1),"\n")

print("Mean Absolute Error:",mean_absolute_error(y1_test,predgbr1))
print("Mean Squared Error:",mean_squared_error(y1_test,predgbr1))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y1_test,predgbr1)))
# Out:
# r2_score= 0.9999402219987304
#
# Mean Absolute Error: 70.78309423552642
# Mean Squared Error: 75334.36624768257
# Root Meand Squared Error: 274.47106632153884

# %% [markdown]
# Obs- By applying the best parameters , we can see GradientBoostingRegressor has given r2_score of  0.9999402219987304

# %% [markdown]
# ### Saving the best Regressor model for Votes

# %%
import joblib

joblib.dump(rental_best,'rental_best.obj')
# Out:
# ['rental_best.obj']

# %%
rental_best_model=joblib.load('rental_best.obj')

# %%
# Viewing Attributes of the best model
rental_best_model
# Out:
# GradientBoostingRegressor(max_features='auto', random_state=32)

# %% [markdown]
# ### Prediction

# %%
ori1 = np.array(y1_test)
predicted1 = np.array(rental_best_model.predict(x1_test))
df_new1 = pd.DataFrame({"Original":ori1,"Predicted":predicted1},index= range(len(ori1)))
df_new1.sample(10)
# Out:
#       Original     Predicted
# 906      22000  21998.208620
# 135       6000   6011.611390
# 195      25000  24997.364059
# 878      11000  11007.446846
# 669      13000  12950.525410
# 459      16000  16023.213745
# 117      40000  40013.426641
# 649      15000  15001.553072
# 33        6000   6009.939828
# 1069     20000  19955.423893

# %% [markdown]
# Obs- We can see our best model is giving fairly good results

# %%
# Viewing the difference of prediction using Visualization 
plt.figure(figsize=(12,7))
sns.kdeplot(data=df_new1, palette='gist_rainbow_r',gridsize=900, shade=True)
plt.title('Original vs predicted  graph')
# Out:
# Text(0.5, 1.0, 'Original vs predicted  graph')

# %% [markdown]
# Obs-We can see the the predicted graph follows original graph

# %% [markdown]
# ### Concluding Remarks for(Approach 1: 'Regression Model' to find Rental Price)

# %% [markdown]
# * We predicted the 'Rental Price' of Rental Properties containing data from various state of India
#
# * We found the output of "Rental Price" using regression model
#
#
# * The r2_score of these models were then checked, and also cross-validation was performed to avoid overfitting of models. E The models  Decision Tree Regressor, and Random Forest Regressor and Gradient Boosting Regressor gave good r2_score or cv-score, but choose Gradient Boosting Regressor for hyper parameter tuning, hence selected it as the best model.
#
#
# * The best model, i.e rental_best_model = GradientBoostingRegressor gave r2_score= 0.9999402219987304

# %% [markdown]
# ## (Approach 2: 'Regression Model to find Area)

# %% [markdown]
# ### Data Preprocessing
#
# ### Seperating Input and Target variables

# %%
x2=df.drop(columns='Area')
y2=df['Area']

# %%
x2.shape
# Out:
# (5019, 8)

# %%
x2.shape
# Out:
# (5019, 8)

# %% [markdown]
# ### Data Transformation to treat Skewness

# %%
x2.skew()
# Out:
# Address          -0.117403
# City              0.833791
# State Code        0.094096
# Rental Price      3.803484
# Deposit           3.803484
# No of Beds        0.253588
# No of Bathroom    0.253588
# Parking          -0.305236
# dtype: float64

# %% [markdown]
# Obs- Keeping the acceptable range as +/-0.5, we can see skewness is present in columns: 'Rental Price','Deposit'
#
# * But since, 'Address','City','State Code' are categorical columns , will not treat the skewness of these columns

# %% [markdown]
# #### Applying Transformation Method

# %%
x2=pd.DataFrame(x2)
from sklearn.preprocessing import PowerTransformer
pt = PowerTransformer(method='box-cox') 
skew_col = ['Rental Price','Deposit'] 
x2[skew_col]= pt.fit_transform(x2[skew_col].values)

# %%
# Rechecking the skewness
x2.skew()
# Out:
# Address          -0.117403
# City              0.833791
# State Code        0.094096
# Rental Price     -0.016785
# Deposit          -0.016785
# No of Beds        0.253588
# No of Bathroom    0.253588
# Parking          -0.305236
# dtype: float64

# %% [markdown]
# Obs- We can see skewness have been removed from the columns

# %% [markdown]
# ### Data Scaling

# %%
from sklearn.preprocessing import StandardScaler
st=StandardScaler()
x2_scale=st.fit_transform(x2)
x2_scale=pd.DataFrame(x2_scale,columns=x2.columns)

# %%
x2=pd.DataFrame(data=x2_scale)

# %% [markdown]
# ### Checking Multi-Collinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def vif_cal1():
    vif1=pd.DataFrame()
    vif1['VIF Factor']=[variance_inflation_factor(x2.values,i)for i in range(x2.shape[1])]
    vif1['Features']=x2.columns
    print(vif1)

vif_cal1()
# Out:
#      VIF Factor        Features
# 0  1.005802e+00         Address
# 1  1.127980e+00            City
# 2  1.030075e+00      State Code
# 3  9.007199e+15    Rental Price
# 4  9.007199e+15         Deposit
# 5           inf      No of Beds
# 6           inf  No of Bathroom
# 7  1.055994e+00         Parking

# %% [markdown]
# Obs- We can see multicollinearity is not present between any columns

# %% [markdown]
# ### Data Modelling

# %%
# Finding Best Random State
maxAccu=0
maxRS=0
for i in range(1,200):
    x2_train,x2_test,y2_train,y2_test = train_test_split(x2,y2,test_size=.25, random_state =i)
    lr = LinearRegression()
    lr.fit(x2_train, y2_train)
    pred2 = lr.predict(x2_test)
    acc=r2_score(y2_test, pred2)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.6630017821148804  on Random_state  87

# %% [markdown]
# #### Splitting data into Train-Test

# %%
x2_train,x2_test,y2_train,y2_test=train_test_split(x2,y2,test_size=0.25,random_state=maxRS)

# %%
x2_train.shape
# Out:
# (3764, 8)

# %%
y2_train.shape
# Out:
# (3764,)

# %%
x2_test.shape
# Out:
# (1255, 8)

# %%
y2_test.shape
# Out:
# (1255,)

# %% [markdown]
# ### Using various Machine Learning Algorithms

# %% [markdown]
# #### 1. Linear Regression

# %%
lr=LinearRegression()
lr.fit(x2_train,y2_train)
lr.score(x2_train,y2_train)
# Out:
# 0.6147927329702855

# %%
predlr2=lr.predict(x2_test)
print("The performance metrix of Linear Regression is as below \n")
print("r2_score=",r2_score(y2_test,predlr2),"\n")

print("Mean Absolute Error:",mean_absolute_error(y2_test,predlr2))
print("Mean Squared Error:",mean_squared_error(y2_test,predlr2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,predlr2)))
# Out:
# The performance metrix of Linear Regression is as below
#
# r2_score= 0.6630017821148804
#
# Mean Absolute Error: 285.9416231389066
# Mean Squared Error: 145413.97904704846
# Root Meand Squared Error: 381.33184898071187

# %% [markdown]
# #### 2. Support Vector Regressor

# %%
svr=SVR()
svr.fit(x2_train,y2_train)
svr.score(x2_train,y2_train)
# Out:
# 0.2912776642609548

# %%
predsvr2=svr.predict(x2_test)
print("The performance metrix of Support Vector Regressor is as below \n")
print("r2_score=",r2_score(y2_test,predsvr2),"\n")

print("Mean Absolute Error:",mean_absolute_error(y2_test,predsvr2))
print("Mean Squared Error:",mean_squared_error(y2_test,predsvr2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,predsvr2)))
# Out:
# The performance metrix of Support Vector Regressor is as below
#
# r2_score= 0.32428495778928546
#
# Mean Absolute Error: 399.26970239651587
# Mean Squared Error: 291569.5329383015
# Root Meand Squared Error: 539.9717890207797

# %% [markdown]
# #### 3. Decision Tree Regressor

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x2_train,y2_train)
dtr.score(x2_train,y2_train)
# Out:
# 0.9809854196656942

# %%
preddtr2=dtr.predict(x2_test)
print("The performance metrix of Decision Tree Regressor is as below \n")
print("r2_score=",r2_score(y2_test,preddtr2),"\n")

print("Mean Absolute Error:",mean_absolute_error(y2_test,preddtr2))
print("Mean Squared Error:",mean_squared_error(y2_test,preddtr2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,preddtr2)))
# Out:
# The performance metrix of Decision Tree Regressor is as below
#
# r2_score= 0.5470192242756595
#
# Mean Absolute Error: 303.9284272434073
# Mean Squared Error: 195460.19395375415
# Root Meand Squared Error: 442.10880329818605

# %% [markdown]
# #### 4. K Neighbors Regressor

# %%
knr=KNeighborsRegressor()
knr.fit(x2_train,y2_train)
knr.score(x2_train,y2_train)
# Out:
# 0.7792523491449419

# %%
predknr2=knr.predict(x2_test)
print("The performance metrix of K Neighbors Regressor is as below \n")
print("r2_score=",r2_score(y2_test,predknr2),"\n")

print("Mean Absolute Error:",mean_absolute_error(y2_test,predknr2))
print("Mean Squared Error:",mean_squared_error(y2_test,predknr2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,predknr2)))
# Out:
# The performance metrix of K Neighbors Regressor is as below
#
# r2_score= 0.7119176840914456
#
# Mean Absolute Error: 252.96127490039842
# Mean Squared Error: 124306.8764940239
# Root Meand Squared Error: 352.5718033167484

# %% [markdown]
# #### 5.Random Forest Regressor

# %%
rfr=RandomForestRegressor()
rfr.fit(x2_train,y2_train)
rfr.score(x2_train,y2_train)
# Out:
# 0.941303149756809

# %%
predrfr2=rfr.predict(x2_test)
print("The performance metrix of Random Forest Regressor is as below \n")
print("r2_score=",r2_score(y2_test,predrfr2),"\n")

print("Mean Absolute Error:",mean_absolute_error(y2_test,predrfr2))
print("Mean Squared Error:",mean_squared_error(y2_test,predrfr2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,predrfr2)))
# Out:
# The performance metrix of Random Forest Regressor is as below
#
# r2_score= 0.7308362297268749
#
# Mean Absolute Error: 242.89864937833303
# Mean Squared Error: 116143.56626676104
# Root Meand Squared Error: 340.79842468350853

# %% [markdown]
# #### 6.Ada Boost Regressor

# %%
adr=AdaBoostRegressor()
adr.fit(x2_train,y2_train)
adr.score(x2_train,y2_train)
# Out:
# 0.3707754510582938

# %%
predadr2=adr.predict(x2_test)
print("The performance metrix of Ada Boost Regressor is as below \n")
print("r2_score=",r2_score(y2_test,predadr2),"\n")

print("Mean Absolute Error:",mean_absolute_error(y2_test,predadr2))
print("Mean Squared Error:",mean_squared_error(y2_test,predadr2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,predadr2)))
# Out:
# The performance metrix of Ada Boost Regressor is as below
#
# r2_score= 0.35579125104049736
#
# Mean Absolute Error: 441.01658152150594
# Mean Squared Error: 277974.6377028505
# Root Meand Squared Error: 527.2330013408214

# %% [markdown]
# #### 7.Gradient Boosting Regressor

# %%
gbr=GradientBoostingRegressor()
gbr.fit(x2_train,y2_train)
gbr.score(x2_train,y2_train)
# Out:
# 0.7428840431818615

# %%
predgbr2=gbr.predict(x2_test)
print("The performance metrix of Gradient Boosting Regressor is as below \n")
print("r2_score=",r2_score(y2_test,predgbr2),"\n")

print("Mean Absolute Error:",mean_absolute_error(y2_test,predgbr2))
print("Mean Squared Error:",mean_squared_error(y2_test,predgbr2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,predgbr2)))
# Out:
# The performance metrix of Gradient Boosting Regressor is as below
#
# r2_score= 0.7495186538677171
#
# Mean Absolute Error: 240.6724805746874
# Mean Squared Error: 108082.14193753626
# Root Meand Squared Error: 328.75848572703984

# %% [markdown]
# #### Regularization to overcome Over-Fitting (Lasso,Ridge)

# %% [markdown]
# #### 8. Lasso Regression

# %%
ls=Lasso(alpha=0.1)
ls.fit(x2_train,y2_train)
ls.score(x2_train,y2_train)
# Out:
# 0.6134846793845623

# %%
predls2=ls.predict(x2_test)
print("The performance metrix of Lasso Regressor is as below \n")
print("r2_score=",r2_score(y2_test,predls2),"\n")
print("Mean Absolute Error:",mean_absolute_error(y2_test,predls2))
print("Mean Squared Error:",mean_squared_error(y2_test,predls2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,predls2)))
# Out:
# The performance metrix of Lasso Regressor is as below
#
# r2_score= 0.6605358149908227
#
# Mean Absolute Error: 286.4852185959397
# Mean Squared Error: 146478.03835857476
# Root Meand Squared Error: 382.724494066652

# %% [markdown]
# #### 9. Ridge Regression

# %%
rg=Ridge(alpha=0.1)
rg.fit(x2_train,y2_train)
rg.score(x2_train,y2_train)
# Out:
# 0.6134848051835378

# %%
predrg2=rg.predict(x2_test)
print("The performance metrix of Ridge Regressor is as below \n")
print("r2_score=",r2_score(y2_test,predrg2),"\n")

print("Mean Absolute Error:",mean_absolute_error(y2_test,predrg2))
print("Mean Squared Error:",mean_squared_error(y2_test,predrg2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,predrg2)))
# Out:
# The performance metrix of Ridge Regressor is as below
#
# r2_score= 0.6605217075862209
#
# Mean Absolute Error: 286.49071085762193
# Mean Squared Error: 146484.12567218152
# Root Meand Squared Error: 382.7324465892349

# %% [markdown]
# ### Cross Validation

# %%
# cv score for Linear Regression 
cvlr2=cross_val_score(lr,x2,y2,cv=5).mean()
print('CV score  for Linear rgerssion:',cvlr2)
print("And Difference between CV and r2_score =", r2_score(y2_test,predlr2)-cvlr2)
# Out:
# CV score  for Linear rgerssion: 0.41481809511373874
# And Difference between CV and r2_score = 0.24818368700114163

# %%
# cv score for Support Vector Regressor
cvsvr2=cross_val_score(svr,x2,y2,cv=5).mean()
print('CV score  for Support Vector Regressor:',cvsvr2)
print("And Difference between CV and r2_score =", r2_score(y2_test,predsvr2)-cvsvr2)
# Out:
# CV score  for Support Vector Regressor: 0.22892051758505713
# And Difference between CV and r2_score = 0.09536444020422832

# %%
# cv score for Decision Tree Regressor
cvdtr2=cross_val_score(dtr,x2,y2,cv=5).mean()
print('CV score  for Decision Tree Regressor:',cvdtr2)
print("And Difference between CV and r2_score =", r2_score(y2_test,preddtr2)-cvdtr2)
# Out:
# CV score  for Decision Tree Regressor: 0.2261944744447018
# And Difference between CV and r2_score = 0.3208247498309577

# %%
# cv score for K Neighbors Regressor
cvknr2=cross_val_score(knr,x2,y2,cv=5).mean()
print('CV score  for K Neighbors Regressor:',cvknr2)
print("And Difference between CV and r2_score =", r2_score(y2_test,predknr2)-cvknr2)
# Out:
# CV score  for K Neighbors Regressor: 0.5512989791392846
# And Difference between CV and r2_score = 0.16061870495216102

# %%
# cv score for Random Forest Regressor
cvrfr2=cross_val_score(rfr,x2,y2,cv=5).mean()
print('CV score  for Random Forest Regressor:',cvrfr2)
print("And Difference between CV and r2_score =", r2_score(y2_test,predrfr2)-cvrfr2)
# Out:
# CV score  for Random Forest Regressor: 0.5542025559829662
# And Difference between CV and r2_score = 0.1766336737439087

# %%
# cv score for Gradient Boosting Regressor
cvgbr2=cross_val_score(gbr,x2,y2,cv=5).mean()
print('CV score  for Gradient Boosting Regressor:',cvgbr2)
print("And Difference between CV and r2_score =", r2_score(y2_test,predgbr2)-cvgbr2)
# Out:
# CV score  for Gradient Boosting Regressor: 0.5815582639319289
# And Difference between CV and r2_score = 0.1679603899357882

# %%
# cv score for Ada Boost Regressor
cvadr2=cross_val_score(adr,x2,y2,cv=5).mean()
print('CV score  for Ada Boost Regressor:',cvadr2)
print("And Difference between CV and r2_score =", r2_score(y2_test,predadr2)-cvadr2)
# Out:
# CV score  for Ada Boost Regressor: 0.2880238891089774
# And Difference between CV and r2_score = 0.06776736193151994

# %%
# cv score for Lasso Regressor
cvls2=cross_val_score(ls,x2,y2,cv=5).mean()
print('CV score  for Lasso Regressor:',cvls2)
print("And Difference between CV and r2_score =", r2_score(y2_test,predls2)-cvls2)
# Out:
# CV score  for Lasso Regressor: 0.49785750096696635
# And Difference between CV and r2_score = 0.16267831402385635

# %%
# cv score for Ridge Regressor
cvrg2=cross_val_score(rg,x2,y2,cv=5).mean()
print('CV score  for Ridge Regressor:',cvrg2)
print("And Difference between CV and r2_score =", r2_score(y2_test,predrg2)-cvrg2)
# Out:
# CV score  for Ridge Regressor: 0.4975931090996548
# And Difference between CV and r2_score = 0.16292859848656605

# %% [markdown]
# ##### Obs-
# * ###### Unfortunately, all the models are giving very low cv_score, as well as r2_score and thus we can say all the machine learning algorithms are not very much suitable for this dataset
#
# * ###### The difference between r2_score and cv score is least in Ada Boost Regressor, but it is giving less CV score,and even Support Vector Regressor diff is least, but its r2_score is also low, therefore performing Hyper Parameter Tuning on 'Gradient Boosting Regressor' and selecting it as the best model

# %% [markdown]
# ### Hyper Parameter Tuning

# %%
#Selecting few parameter list to pass in Gradient Boosting Regressor
from sklearn.model_selection import GridSearchCV
# defining parameter range
parameter = {'criterion':['friedman_mse', 'squared_error'], 
             'loss':['squared_error', 'absolute_error', 'huber', 'quantile'],
             'random_state': [24,32,44,74,112],
             'max_features':['auto', 'sqrt', 'log2']}

# %%
# Start Tuning 
gbr2=GradientBoostingRegressor()
GCV = GridSearchCV(gbr2,parameter,cv=5)

GCV.fit(x2_train,y2_train)  
print(GCV.best_params_)
# Out:
# {'criterion': 'squared_error', 'loss': 'squared_error', 'max_features': 'auto', 'random_state': 32}

# %%
#Applying best parameter values on Gradient Boossting Regressor Algorithm 
area_best=GradientBoostingRegressor(criterion='squared_error', loss= 'squared_error', max_features= 'auto', random_state= 32)
area_best.fit(x2_train,y2_train)
area_best.score(x2_train,y2_train)
# Out:
# 0.7428840431818615

# %%
predgbr2=area_best.predict(x2_test)
print("r2_score=",r2_score(y2_test,predgbr2),"\n")

print("Mean Absolute Error:",mean_absolute_error(y2_test,predgbr2))
print("Mean Squared Error:",mean_squared_error(y2_test,predgbr2))
print("Root Meand Squared Error:",np.sqrt(mean_squared_error(y2_test,predgbr2)))
# Out:
# r2_score= 0.7495720266153723
#
# Mean Absolute Error: 240.60971962821347
# Mean Squared Error: 108059.11171601783
# Root Meand Squared Error: 328.72345781221304

# %% [markdown]
# Obs- By applying the best parameters , we can see GradientBoostingRegressor has given r2_score of 0.7495720266153723

# %% [markdown]
# ### Saving the best Regressor model for Gross_Collection

# %%
import joblib

joblib.dump(area_best,'area_best.obj')
# Out:
# ['area_best.obj']

# %%
area_best_model=joblib.load('area_best.obj')

# %%
# Viewing Attributes of the best model
area_best_model
# Out:
# GradientBoostingRegressor(criterion='squared_error', max_features='auto',
#                           random_state=32)

# %% [markdown]
# ### Prediction

# %%
ori2 = np.array(y2_test)
predicted2 = np.array(area_best_model.predict(x2_test))
df_new2 = pd.DataFrame({"Original":ori2,"Predicted":predicted2},index= range(len(ori1)))
df_new2.sample(10)
# Out:
#      Original    Predicted
# 488      1569  1835.970137
# 843      1300  1452.475530
# 725      1700  1911.339442
# 757      2500  2069.289835
# 560      1384  1866.036209
# 291      2600  1839.627711
# 197      1700  1097.825109
# 160       594   948.941465
# 605       900   453.844747
# 338      1102  1179.874605

# %% [markdown]
# Obs- We can see our best model is giving average results

# %%
# Viewing the difference of prediction using Visualization 
plt.figure(figsize=(12,7))
sns.kdeplot(data=df_new2, palette='gist_rainbow_r',gridsize=900, shade=True)
plt.title('Original vs predicted  graph')
# Out:
# Text(0.5, 1.0, 'Original vs predicted  graph')

# %% [markdown]
# Obs-We can see the the predicted graph is exceeding the original graph mojarly.

# %% [markdown]
# ### Concluding Remarks for(Approach 2: 'Regression Model' to find Area)

# %% [markdown]
# * We predicted the outcome of 'Area' of Rental properties from different states of India.
#
#
# * We found the output of "Area" using regression model
#
#
# * The r2_score of these models were then checked, and also cross-validation was performed to avoid overfitting of models.The models didnot gave very good r2_score or cv-score, and after applying hyper parameter tuning, considerable better results were observed.
#
#
# * The best model, i.e  area_best_model=GradientBoostingRegressor gave r2_score= 0.7495720266153723

# %% [markdown]
# ### Overall Conclusion

# %% [markdown]
# ### Introduction of the Project:
#
# This Capstone Project provided a valuable learning experience from collecting and scraping rental property information to exploring relationships in the data
#
# ### Data Collection and Cleaning:
#
# During the data collection phase, several challenges were encountered, with missing data in key columns such as 'Deposit' and 'No of Bathroom' posing significant obstacles. Notably, the website from which the rental data was scraped did not provide information on deposits, number of bathrooms, or detailed amenities.
#
# The 'Deposit' column presented a notable gap, as the information was entirely absent from the website listings. To address this, a careful decision was made to impute deposit values by twinning them with the corresponding rental prices. This approach was considered a reasonable approximation given the lack of specific deposit details.
#
# Similarly, the 'No of Bathroom' column posed a challenge, as the website did not specify the number of bathrooms for many listings. To navigate this issue, a pragmatic decision was made to assume that the number of bathrooms is equal to the number of bedrooms. While this assumption may introduce some level of imprecision, it was deemed a reasonable compromise to ensure the inclusion of this critical variable in the analysis.
# ### Exploratory Data Analysis (EDA):
#
# It was the first time doing EDA on a self-created CSV file
#
# ### Modeling Approach:
#
# We successfully built predictive models for Rental Price and Area, with Model 1 yielding favorable results
#
# ### Model Evaluation:
#
# Model 1 (Rental Price prediction)gave fairly good results, while Model2(Area Prediction) gave average results
#
# ### Challenges and Limitations:
#
# One of the primary challenges encountered during this project was the absence of comprehensive amenity data in the scraped rental information from various cities across India. Unfortunately, many rental property listings did not provide details on amenities, making it difficult to incorporate this crucial aspect into our analysis. As a result, the analysis and modeling phases had to be adapted to accommodate this limitation. It's important to acknowledge that the quality of insights derived from the dataset may be affected by the lack of detailed amenity information.
#
# ### Future Enhancements:
#
# Future enhancements could involve further segmentation of rental properties country-wise to enhance the predictive capabilities of the models. This project not only honed technical skills but also provided insights into the complexities of real-world data. As we conclude this project, the lessons learned will undoubtedly contribute to future data science endeavors.
